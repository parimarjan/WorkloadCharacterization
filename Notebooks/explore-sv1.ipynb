# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
from collections import defaultdict
import os

from IPython.display import HTML
from IPython.display import display_html

# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append("..")
from utils.utils import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# FN = "combined-0J-2021-05-22.ss.csv"
# INP_FIELD = "NormInput"
# DEDUP_FIELDS = [INP_FIELD, FILTER_FIELD]

FN = "../data/cosmos15/raw_views_sv1_2021-12-15.ss.csv"
#DEDUPFN = FN.replace(".ss.csv", "-dedup.ss.csv")
INP_FIELD = "NormInputHashCode"
FILTER_FIELD = "FilterExpr"

# %%
df = pd.read_csv(FN, sep="\t")

# %%
df.head(10)
# Out:
#                                 JobGUID          HashTagInput  \
# 0  0d7b769f-3d15-4336-89c0-66e1a42664ef   8319415751745435240
# 1  0d7b769f-3d15-4336-89c0-66e1a42664ef   8319415751745435240
# 2  0d7b769f-3d15-4336-89c0-66e1a42664ef   8319415751745435240
# 3  141687dc-d7c9-4c9c-81c8-c8bed4f698bd   1894115245309555606
# 4  141687dc-d7c9-4c9c-81c8-c8bed4f698bd   1894115245309555606
# 5  392309e0-73a5-4662-8563-8f1118b11a1f  15215909868762634803
# 6  141687dc-d7c9-4c9c-81c8-c8bed4f698bd   1894115245309555606
# 7  392309e0-73a5-4662-8563-8f1118b11a1f  15215909868762634803
# 8  141687dc-d7c9-4c9c-81c8-c8bed4f698bd   1894115245309555606
# 9  392309e0-73a5-4662-8563-8f1118b11a1f  15215909868762634803
#
#         OperatorName  EstCardinality  InputCardinality  AvgRowLength  \
# 0        PhyOp_Range    3.561150e+10      3.561150e+10         226.0
# 1         PhyOp_Sort    3.561150e+10      3.561150e+10         226.0
# 2  PhyOp_StreamGbAgg    8.902870e+09      3.561150e+10         226.0
# 3        PhyOp_Range    9.542420e+05      9.542420e+05        1619.0
# 4      PhyOp_Process    9.542420e+05      9.542420e+05         293.0
# 5        PhyOp_Range    2.006470e+09      2.006470e+09          74.0
# 6    PhyOp_HashGbAgg    4.771210e+05      9.542420e+05         293.0
# 7       PhyOp_Filter    8.218490e+08      2.006470e+09          55.0
# 8         PhyOp_Sort    4.771210e+05      9.542420e+05         293.0
# 9      PhyOp_Process    8.218490e+08      2.006470e+09          55.0
#
#   Partitioning  PartitioningColumn  Partitions  \
# 0         Hash       device_id:ASC        2500
# 1         Hash       device_id:ASC        2500
# 2         Hash       device_id:ASC        2500
# 3         Hash        FlightId:ASC           2
# 4          NaN                 NaN           2
# 5        Range  watsonReportId:ASC         207
# 6          NaN                 NaN           2
# 7        Range  watsonReportId:ASC         207
# 8          NaN                 NaN           2
# 9        Range  watsonReportId:ASC         207
#
#                                           SortColumn  NormInputHashCode  \
# 0                                      device_id ASC        -1196440515
# 1  device_id ASC,deviceClass ASC,osVer ASC,osBuil...        -1196440515
# 2  device_id ASC,deviceClass ASC,osVer ASC,osBuil...        -1196440515
# 3                                       FlightId ASC        -1299802904
# 4                                             #NULL#        -1299802904
# 5     watsonReportId ASC,FailureInfo_FailureHash ASC         -632716426
# 6                                             #NULL#        -1299802904
# 7                                             #NULL#         -632716426
# 8  FlightId ASC,_ts DESC,FlightingNamespace ASC,F...        -1299802904
# 9                                             #NULL#         -632716426
#
#       RowCount Selectivity  InclusiveTime  ExclusiveTime  VertexCount  \
# 0  14879988788           0      35507.468       1292.213         2500
# 1  14879988788           0      35507.468       1292.213         2500
# 2   7386366085           0      42227.262        739.528         2500
# 3        58519           0          0.253          0.064            2
# 4        58519           0          0.737          0.484            2
# 5    263068200           0       2089.764         60.068          207
# 6        58519           0          1.389          0.250            2
# 7    258432604           0       2111.094         21.330          207
# 8        58519           0          1.389          0.250            2
# 9    258432604           0       2655.600         32.028          207
#
#    VirtualClusterQueueLength       JobVirtualCluster  \
# 0                         65      asimov.partner.ptp
# 1                         65      asimov.partner.ptp
# 2                         65      asimov.partner.ptp
# 3                         59  asimov.partner.datafun
# 4                         59  asimov.partner.datafun
# 5                        129        asimov.prod.jobs
# 6                         59  asimov.partner.datafun
# 7                        129        asimov.prod.jobs
# 8                         59  asimov.partner.datafun
# 9                        129        asimov.prod.jobs
#
#                                           FilterExpr
# 0                                             #NULL#
# 1                                             #NULL#
# 2                                             #NULL#
# 3                                             #NULL#
# 4                                             #NULL#
# 5                                             #NULL#
# 6                                             #NULL#
# 7  {"isComparison":false,"expOperator":"And","att...
# 8                                             #NULL#
# 9  {"isComparison":false,"expOperator":"And","att...

# %%
print(df.keys())
# Out:
# Index(['JobGUID', 'HashTagInput', 'OperatorName', 'EstCardinality',
#        'InputCardinality', 'AvgRowLength', 'Partitioning',
#        'PartitioningColumn', 'Partitions', 'SortColumn', 'NormInputHashCode',
#        'RowCount', 'Selectivity', 'InclusiveTime', 'ExclusiveTime',
#        'VertexCount', 'VirtualClusterQueueLength', 'JobVirtualCluster',
#        'FilterExpr'],
#       dtype='object')
