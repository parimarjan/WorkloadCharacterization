# %%
import pandas as pd
import json

# %%
with open("../db1_queries.json", "r") as f:
    data = json.loads(f.read())

# %%
sqls = [data[k]["sql"] for k in data]
params = [data[k]["params"] for k in data]

# %%
params
# Out:
# [[[15359, 0.0061],
#   [15359, 0.0911],
#   [15359, 0.5964],
#   [15359, 12.9291],
#   [15359, 48.8129],
#   [15359, 60.127],
#   [15359, 68.0368],
#   [15446, 0.0061],
#   [15446, 0.0911],
#   [15446, 0.5964],
#   [15446, 12.9291],
#   [15446, 48.8129],
#   [15446, 60.127],
#   [15446, 68.0368],
#   [15525, 0.0061],
#   [15525, 0.0911],
#   [15525, 0.5964],
#   [15525, 12.9291],
#   [15525, 48.8129],
#   [15525, 60.127],
#   [15525, 68.0368],
#   [15714, 0.0061],
#   [15714, 0.0911],
#   [15714, 0.5964],
#   [15714, 12.9291],
#   [15714, 48.8129],
#   [15714, 60.127],
#   [15714, 68.0368],
#   [15905, 0.0061],
#   [15905, 0.0911],
#   [15905, 0.5964],
#   [15905, 12.9291],
#   [15905, 48.8129],
#   [15905, 60.127],
#   [15905, 68.0368],
#   [15982, 0.0061],
#   [15982, 0.0911],
#   [15982, 0.5964],
#   [15982, 12.9291],
#   [15982, 48.8129],
#   [15982, 60.127],
#   [15982, 68.0368],
#   [16066, 0.0061],
#   [16066, 0.0911],
#   [16066, 0.5964],
#   [16066, 12.9291],
# ...

# %%
sqls
# Out:
# ['SELECT d1_label, COUNT(*) as cnt FROM dim1, fact WHERE d1_id = f_d1_id AND f_p1 < {} AND f_p8 < {} GROUP BY d1_label ORDER BY cnt',
#  'SELECT d1_label, COUNT(*) as cnt FROM dim1, fact WHERE d1_id = f_d1_id AND f_p2 < {} AND f_p9 < {} GROUP BY d1_label ORDER BY cnt',
#  'SELECT d1_label, COUNT(*) as cnt FROM dim1, fact WHERE d1_id = f_d1_id AND f_p3 < {} AND f_p10 < {} GROUP BY d1_label ORDER BY cnt',
#  '\nSELECT d1_label, COUNT(*) as cnt \nFROM dim1, fact \nWHERE d1_id = f_d1_id \nAND (f_p4 < {} OR f_p5 < {})\nAND (f_p6 < {} OR f_p7 < {})\nAND (f_p11 < {} OR f_p12 < {})\nGROUP BY d1_label ORDER BY cnt\n',
#  "\nselect d3_label, sum(f_amt) as total \nfrom dim3, fact \nwhere d3_id = f_d3_id \nand f_type='{}' \ngroup by d3_label \norder by total desc \nlimit 20;\n",
#  '\nselect d2_label, sum(attrib_share * f_amt) as total \nfrom dim2, attrib, fact \nwhere d2_id = attrib_d2_id\nand f_id = attrib_f_id\nand f_amt > {}\ngroup by d2_label \norder by total desc \n',
# ...
